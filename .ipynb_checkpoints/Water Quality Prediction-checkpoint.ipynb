# %%
import pandas as pd
import matplotlib.pyplot as mplt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv(r'C:\Users\thesu\OneDrive\Documents\water_potability.csv')

# %%
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %% [markdown]
# # Data Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# Here, we see that the median for Potability 1 and 0 are both, we can fill the missing values with the median

data[data['Potability']==0][['ph','Sulfate','Trihalomethanes']].median()
data[data['Potability']==1][['ph','Sulfate','Trihalomethanes']].median()
data['ph'].fillna(value=data['ph'].median(),inplace=True)
data['Sulfate'].fillna(value=data['Sulfate'].median(),inplace=True)
data['Trihalomethanes'].fillna(value=data['Trihalomethanes'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.036752  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.073546
# 2     8.099124  224.236259  19909.541732     9.275884  333.073546
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.073546
# 3273  9.419510  175.762646  33155.578218     7.350233  333.073546
# 3274  5.126763  230.603758  11983.869376     6.303357  333.073546
# 3275  7.874671  195.102299  17404.177061     7.509306  333.073546
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.shape
# Out:
# (3276, 10)

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.074194   196.369496  22014.092526     7.122277   333.608364
# std       1.470040    32.879761   8768.570828     1.583085    36.143851
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.407478     3.966786     0.390110
# std       80.824064        3.308162        15.769958     0.780382     0.487849
# ...

# %% [markdown]
# #### IQR

# %%
def single_iqr(x):
  return np.subtract(*np.percentile(x, [75, 25]))

# %%
IQR = pd.DataFrame(data)
IQR.apply(single_iqr)
# Out:
# ph                     1.592377
# Hardness              39.816918
# Solids             11666.071830
# Chloramines            1.987466
# Sulfate               33.291119
# Conductivity         116.057890
# Organic_carbon         4.491850
# Trihalomethanes       20.018954
# Turbidity              1.060609
# Potability             1.000000
# dtype: float64

# %% [markdown]
# ##### Cat Frequency

# %%
data.Potability.value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
data.Potability.value_counts().plot(kind="bar", color=["orange", "salmon"])
mplt.show()

# %%
zero  = data[data['Potability']==0]   #zero values in Potability column
one = data[data['Potability']==1]  # one values in Potability column
from sklearn.utils import resample
#minority class that  is 1, we need to upsample/increase that class so that there is no bias
#n_samples = 1998 means we want 1998 sample of class 1, since there are 1998 samples of class 0
df_minority_upsampled = resample(one, replace = True, n_samples = 1998) 
#concatenate
data = pd.concat([zero, df_minority_upsampled])

from sklearn.utils import shuffle
data = shuffle(data) # shuffling so that there is particular sequence

# %%
data.Potability.value_counts().plot(kind="bar", color=["orange", "salmon"])
mplt.show()

# %%
data.Potability.value_counts()
# Out:
# 1    1998
# 0    1998
# Name: Potability, dtype: int64

# %%
data.boxplot(figsize=(14,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Histogram

# %%
data.hist(figsize=(13,12))
mplt.show()

# %% [markdown]
# #### Visualizing with pairplot

# %%
data.reset_index(inplace=True)
sns.pairplot(data)
mplt.show()

# %% [markdown]
# #### Correlation Matrix

# %%
size = 10

# %%
df = pd.DataFrame(data)
 
corrM = df.corr()
sns.heatmap(corrM, annot=True)
figure = mplt.gcf()
figure.set_size_inches(10,8)

mplt.show()

# %% [markdown]
# #### Stratified Sampling

# %%
data.groupby('Potability', group_keys=False).apply(lambda x: x.sample(int(np.rint(size*len(x)/len(df))))).sample(frac=1).reset_index(drop=True)
# Out:
#    index        ph    Hardness        Solids  Chloramines     Sulfate  \
# 0   2563  7.506111  188.221812  31920.584694     5.714312  334.243304
# 1   3162  9.079715  222.042631  53735.899194     6.894915  254.040977
# 2    299  8.075495  195.804996  29483.601854    10.493841  298.737219
# 3    326  3.657123  275.767142  23736.816258     9.100772  333.073546
# 4    231  4.443239  178.956206  25008.532248     4.948815  298.576676
# 5   2968  4.663492  170.951830  41452.625574     8.725765  362.415419
# 6   1930  7.682923  217.788932  31150.513421     8.021668  333.073546
# 7    776  7.036752  155.864382  28224.774178     8.366723  392.582582
# 8   2869  7.171224  199.160175  13163.031278     5.762522  351.278134
# 9   2505  6.917920  223.332959  17862.142732     7.995890  299.402773
#
#    Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0    436.396995       15.220967        43.360494   4.744007           0
# ...

# %% [markdown]
# ## Data Normalization

# %%
from sklearn import preprocessing

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    index         ph    Hardness        Solids  Chloramines     Sulfate  \
# 0   1531   6.692532  200.404351  37033.152091     4.727072  280.844916
# 1   2282  10.524602  256.172323  31965.364041     5.007003  288.565983
# 2    183   6.769573  168.937072  11067.181148     7.121264  305.794950
# 3   2807   7.036752  241.066929  22656.714625     7.293823  333.073546
# 4   2577   7.766114  212.317666  24145.385762     7.925887  364.081412
#
#    Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0    376.672794       12.485257        57.818484   2.942115           1
# 1    505.361417       12.536626        75.343364   4.340987           0
# 2    289.542460       18.545903        62.001571   5.220540           0
# 3    315.604327       16.404805        46.139183   3.735204           1
# 4    464.108595       15.465256        70.105844   4.399902           0

# %%
X = df.drop('Potability',axis=1).values
Y = df['Potability'].values

# %%
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from sklearn.metrics import roc_curve
from sklearn.preprocessing import StandardScaler,MinMaxScaler


def plot_roc_curve(fper, tper):
    mplt.plot(fper, tper, color='red', label='ROC')
    mplt.plot([0, 1], [0, 1], color='green', linestyle='--')
    mplt.xlabel('False Positive Rate')
    mplt.ylabel('True Positive Rate')
    mplt.title('Receiver Operating Characteristic Curve')
    mplt.legend()
    mplt.show()


X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size= 0.2, random_state=101)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)

prediction=logreg.predict(X_test)

accu_lr=accuracy_score(Y_test , prediction)*100
print(f"Accuracy Score = {accuracy_score(Y_test,prediction)*100}")
print(f"Confusion Matrix =\n {confusion_matrix(Y_test,prediction)}")
print(f"Classification Report =\n {classification_report(Y_test,prediction)}")

prob = prediction
fper, tper, thresholds = roc_curve(Y_test, prob)
plot_roc_curve(fper, tper)
# Out:
# Accuracy Score = 49.875
# Confusion Matrix =
#  [[188 211]
#  [190 211]]
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       0.50      0.47      0.48       399
#            1       0.50      0.53      0.51       401
#
#     accuracy                           0.50       800
#    macro avg       0.50      0.50      0.50       800
# weighted avg       0.50      0.50      0.50       800

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rdf=RandomForestClassifier()
rdf.fit(X_train,Y_train)
pre_fit=rdf.predict(X_test)
accu_rf=accuracy_score(Y_test , pre_fit)*100

print(f"Accuracy Score = {accuracy_score(Y_test,pre_fit)*100}")
print(f"Confusion Matrix =\n {confusion_matrix(Y_test,pre_fit)}")
print(f"Classification Report =\n {classification_report(Y_test,pre_fit)}")

prob = pre_fit
fper, tper, thresholds = roc_curve(Y_test, prob)
plot_roc_curve(fper, tper)
# Out:
# Accuracy Score = 94.125
# Confusion Matrix =
#  [[376  23]
#  [ 24 377]]
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       399
#            1       0.94      0.94      0.94       401
#
#     accuracy                           0.94       800
#    macro avg       0.94      0.94      0.94       800
# weighted avg       0.94      0.94      0.94       800

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier


kne=KNeighborsClassifier()
kne.fit(X_train,Y_train)
pred_kne=kne.predict(X_test)
accu_kne=accuracy_score(Y_test , pred_kne)*100

print(f"Accuracy Score = {accuracy_score(Y_test,pred_kne)*100}")
print(f"Confusion Matrix =\n {confusion_matrix(Y_test,pred_kne)}")
print(f"Classification Report =\n {classification_report(Y_test,pred_kne)}")

prob = pred_kne
fper, tper, thresholds = roc_curve(Y_test, prob)
plot_roc_curve(fper, tper)
# Out:
# Accuracy Score = 70.0
# Confusion Matrix =
#  [[264 135]
#  [105 296]]
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       0.72      0.66      0.69       399
#            1       0.69      0.74      0.71       401
#
#     accuracy                           0.70       800
#    macro avg       0.70      0.70      0.70       800
# weighted avg       0.70      0.70      0.70       800

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import roc_curve
svc=SVC(probability=True)
svc.fit(X_train,Y_train)
pre_siv=svc.predict(X_test)

accu_svc=accuracy_score(Y_test , pre_siv)*100
print(f"Accuracy Score = {accuracy_score(Y_test,pre_siv)*100}")
print(f"Confusion Matrix =\n {confusion_matrix(Y_test,pre_siv)}")
print(f"Classification Report =\n {classification_report(pre_siv,prediction)}")

prob = pre_siv
fper, tper, thresholds = roc_curve(Y_test, prob)
plot_roc_curve(fper, tper)
# Out:
# Accuracy Score = 70.625
# Confusion Matrix =
#  [[272 127]
#  [108 293]]
# Classification Report =
#                precision    recall  f1-score   support
#
#            0       0.60      0.59      0.59       380
#            1       0.63      0.64      0.63       420
#
#     accuracy                           0.61       800
#    macro avg       0.61      0.61      0.61       800
# weighted avg       0.61      0.61      0.61       800

# %%
probs_svc = svc.predict_proba(X_test)[:, 1]
probs_kne = kne.predict_proba(X_test)[:, 1]
probs_rdf = rdf.predict_proba(X_test)[:, 1]
probs_lr = logreg.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import roc_auc_score, roc_curve,auc


fpr_svc, tpr_svc, thresholds_svc = roc_curve(Y_test, probs_svc)
auc_svc = auc(fpr_svc, tpr_svc)


fpr_lr, tpr_lr, thresholds_lr = roc_curve(Y_test, probs_lr)
auc_lr = auc(fpr_lr, tpr_lr)


fpr_rdf, tpr_rdf, thresholds_rdf = roc_curve(Y_test, probs_rdf)
auc_rdf = auc(fpr_rdf, tpr_rdf)



fpr_kne, tpr_kne, thresholds_kne = roc_curve(Y_test, probs_kne)
auc_kne = auc(fpr_kne, tpr_kne)

mplt.figure(figsize=(12, 7))
mplt.plot(fpr_svc, tpr_svc, label=f'AUC (SVC) = {auc_svc:.2f}')
mplt.plot(fpr_lr, tpr_lr, label=f'AUC (Logistic Regression) = {auc_lr:.2f}')
mplt.plot(fpr_rdf, tpr_rdf, label=f'AUC (Random Forests) = {auc_rdf:.2f}')
mplt.plot(fpr_kne, tpr_kne, label=f'AUC (KNN) = {auc_kne:.2f}')
mplt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
mplt.title('AUC Curve', size=20)
mplt.xlabel('False Positive Rate', size=14)
mplt.ylabel('True Positive Rate', size=14)
mplt.legend();

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression','RandomForestClassifier','KNeighborsClassifier','SVC'],
    'Score': [ accu_lr,accu_rf, accu_kne, accu_svc]
})

models.sort_values(by = 'Score', ascending = False)

# %% [markdown]
# ## Using Smote

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, Y_train_res = sm.fit_resample(X_train, Y_train.ravel())

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC
from sklearn.metrics import roc_curve
svc=SVC(probability=True)
svc.fit(X_train_res,Y_train_res)
pre_siv=svc.predict(X_test)

print(f"Accuracy Score = {accuracy_score(Y_test,pre_siv)*100}")
print(f"Confusion Matrix =\n {confusion_matrix(Y_test,pre_siv)}")
print(f"Classification Report =\n {classification_report(pre_siv,prediction)}")

prob = pre_siv
fper, tper, thresholds = roc_curve(Y_test, prob)
plot_roc_curve(fper, tper)

# %% [markdown]
# ###  Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
logreg = LogisticRegression()
logreg.fit(X_train_res, Y_train_res)

prediction=logreg.predict(X_test)

accu_lr=accuracy_score(Y_test , prediction)*100
print(f"Accuracy Score = {accuracy_score(Y_test,prediction)*100}")
print(f"Confusion Matrix =\n {confusion_matrix(Y_test,prediction)}")
print(f"Classification Report =\n {classification_report(Y_test,prediction)}")

prob = prediction
fper, tper, thresholds = roc_curve(Y_test, prob)
plot_roc_curve(fper, tper)

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier


kne=KNeighborsClassifier()
kne.fit(X_train_res,Y_train_res)
pred_kne=kne.predict(X_test)
accu_kne=accuracy_score(Y_test , pred_kne)*100
print(f"Accuracy Score = {accuracy_score(Y_test,pred_kne)*100}")
print(f"Confusion Matrix =\n {confusion_matrix(Y_test,pred_kne)}")
print(f"Classification Report =\n {classification_report(Y_test,pred_kne)}")
probs_kne = kne.predict_proba(X_test)[:, 1]

prob = pred_kne
fper, tper, thresholds = roc_curve(Y_test, prob)
plot_roc_curve(fper, tper)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rdf=RandomForestClassifier()
rdf.fit(X_train_res,Y_train_res)
pre_fit=rdf.predict(X_test)
accu_rf=accuracy_score(Y_test , pre_fit)*100
print(f"Accuracy Score = {accuracy_score(Y_test,pre_fit)*100}")
print(f"Confusion Matrix =\n {confusion_matrix(Y_test,pre_fit)}")
print(f"Classification Report =\n {classification_report(Y_test,pre_fit)}")

prob = pre_fit
fper, tper, thresholds = roc_curve(Y_test, prob)
plot_roc_curve(fper, tper)

# %%
probs_svc = svc.predict_proba(X_test)[:, 1]
probs_kne = kne.predict_proba(X_test)[:, 1]
probs_rdf = rdf.predict_proba(X_test)[:, 1]
probs_lr = logreg.predict_proba(X_test)[:, 1]

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression','RandomForestClassifier','KNeighborsClassifier','SVC'],
    'Score': [ accu_lr,accu_rf, accu_kne, accu_svc]
})

models.sort_values(by = 'Score', ascending = False)

# %%
from sklearn.metrics import roc_auc_score, roc_curve,auc


fpr_svc, tpr_svc, thresholds_svc = roc_curve(Y_test, probs_svc)
auc_svc = auc(fpr_svc, tpr_svc)


fpr_lr, tpr_lr, thresholds_lr = roc_curve(Y_test, probs_lr)
auc_lr = auc(fpr_lr, tpr_lr)


fpr_rdf, tpr_rdf, thresholds_rdf = roc_curve(Y_test, probs_rdf)
auc_rdf = auc(fpr_rdf, tpr_rdf)



fpr_kne, tpr_kne, thresholds_kne = roc_curve(Y_test, probs_kne)
auc_kne = auc(fpr_kne, tpr_kne)

mplt.figure(figsize=(12, 7))
mplt.plot(fpr_svc, tpr_svc, label=f'AUC (SVC) = {auc_svc:.2f}')
mplt.plot(fpr_lr, tpr_lr, label=f'AUC (Logistic Regression) = {auc_lr:.2f}')
mplt.plot(fpr_rdf, tpr_rdf, label=f'AUC (Random Forests) = {auc_rdf:.2f}')
mplt.plot(fpr_kne, tpr_kne, label=f'AUC (KNN) = {auc_kne:.2f}')
mplt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Baseline')
mplt.title('AUC Curve', size=20)
mplt.xlabel('False Positive Rate', size=14)
mplt.ylabel('True Positive Rate', size=14)
mplt.legend();
